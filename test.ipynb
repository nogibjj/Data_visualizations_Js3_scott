# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("AI_Companies.csv")
df.drop(columns = "Unnamed: 7", inplace = True)
df.head()
# Out:
#    Company_Name                    Website             Location  \
# 0      Smith.ai          https://smith.ai/        Los Altos, CA
# 1       MooveIt      https://moove-it.com/           Austin, TX
# 2  TechSpeedInc  http://www.techspeed.com/         Portland, OR
# 3       WillDom       https://willdom.com/  Fort Lauderdale, FL
# 4        Icreon  https://www.icreon.com/en         New York, NY
#
#   Minimum Project Size Average Hourly Rate Number of Employees  \
# 0          Undisclosed         Undisclosed           250 - 999
# 1            $100,000+      $50 - $99 / hr            50 - 249
# 2              $1,000+          < $25 / hr            50 - 249
# 3             $10,000+      $50 - $99 / hr           250 - 999
# 4             $50,000+    $100 - $149 / hr           250 - 999
#
#   Percent AI Service Focus
# 0                      10%
# 1                      15%
# 2                      40%
# 3                      10%
# 4                      10%

# %%
df['Average Hourly Rate'].value_counts()
# Out:
# Average Hourly Rate
# Undisclosed         1247
# $25 - $49 / hr       695
# $50 - $99 / hr       506
# < $25 / hr           264
# $100 - $149 / hr     254
# $150 - $199 / hr      80
# $200 - $300 / hr      35
# $300+ / hr            18
# $5,000+                1
# Name: count, dtype: int64

# %%
df.rename(columns ={"Average Hourly Rate":"Average_Hourly_Rate", 'Minimum Project Size': "Minimum_Project_Size", "Number of Employees":"Number_of_Employees","Percent AI Service Focus":'Percent_AI_Service_Focus'}, inplace = True)

df.Number_of_Employees.value_counts()
# Out:
# Number_of_Employees
# 10 - 49           1389
# 50 - 249           774
# 2 - 9              644
# 250 - 999          201
# 1,000 - 9,999       57
# Freelancer          23
# 10,000+             11
# $50 - $99 / hr       1
# Name: count, dtype: int64

# %%
# import pandas as pd
# import numpy as np

# # Sample data
# # df = pd.DataFrame({'Location': ['Los Altos, CA', 'Austin, TX', 'Portland, OR', np.nan, 'New York, NY']})

# us_state_abbreviations = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']

# def assign_country(location):
#     if pd.isna(location):  # Check for NaN values
#         return np.nan  # or return "Unknown" or any other string
#     elif isinstance(location, float):  # Check for other float values
#         return "Unknown"  # or return np.nan or any other string
#     elif location[-2:] in us_state_abbreviations:
#         return "United States"
#     else:
#         return location.split(",")[-1].strip()

# # Apply the function to create a new 'country' column
# df['country'] = df['Location'].apply(assign_country)

# %%
us_state_abbreviations = ['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'FL', 'GA', 'HI', 'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI', 'WY']
# number_of_states = len(us_state_abbreviations)
# print(f"Number of states: {number_of_states}")
# Filter rows where the 'Location' column contains state abbreviations
df_us = df[df['Location'].str[-2:].isin(us_state_abbreviations)]
df_us['state'] = df_us["Location"].str[-2:]
# Out:
# /tmp/ipykernel_1740/2740999914.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_us['state'] = df_us["Location"].str[-2:]

# %%
df_us
# Out:
#                 Company_Name                             Website  \
# 0                   Smith.ai                   https://smith.ai/
# 1                    MooveIt               https://moove-it.com/
# 2               TechSpeedInc           http://www.techspeed.com/
# 3                    WillDom                https://willdom.com/
# 4                     Icreon           https://www.icreon.com/en
# ...                      ...                                 ...
# 3083             SoftwarePro  https://softwaredeveloperspro.com/
# 3089            Zone24x7Inc.               https://zone24x7.com/
# 3095   HurekaTechnologiesInc            http://www.hurekatek.com
# 3096  MYZEALI.T.SolutionsLLC            http://www.myzealit.com/
# 3098                MojoTrek             http://www.mojotrek.com
#
#                  Location Minimum_Project_Size Average_Hourly_Rate  \
# 0           Los Altos, CA          Undisclosed         Undisclosed
# ...

# %%
unique_states_count = df_us['state'].nunique()
print(f"Number of unique states: {unique_states_count}")
# Out:
# Number of unique states: 40

# %%
missing_values_count = df_us['Percent_AI_Service_Focus'].isna().sum()
print(f"Number of missing values in 'Percent_AI_Service_Focus': {missing_values_count}")
# Out:
# Number of missing values in 'Percent_AI_Service_Focus': 0

# %%
df_us['Percent_AI_Service_Focus']
# Out:
# 0       10%
# 1       15%
# 2       40%
# 3       10%
# 4       10%
#        ...
# 3083    10%
# 3089    20%
# 3095    20%
# 3096    10%
# 3098    25%
# Name: Percent_AI_Service_Focus, Length: 897, dtype: object

# %%
print(df.Percent_AI_Service_Focus.unique())
# Out:
# ['10%' '15%' '40%' '20%' '100%' '33%' '11%' '30%' '50%' '90%' '65%' '55%'
#  '60%' '25%' '75%' '80%' '70%' '45%' '12%' '23%' '13%' '22%' '35%' '85%'
#  '17%' '59%' '49%' '34%' '51%' '38%' '16%' '56%' '31%' '19%' '24%' '37%'
#  '50 - 249' '36%' '18%']

# %%
def clean_percentage(value):
    if '-' in value:
        lower, upper = map(int, value.split('-'))
        return int((lower + upper) / 2)
    else:
        return int(value[:-1])  # Assumes that the value ends with a '%' character

df_us['Percent_AI_Service_Focus'] = df_us['Percent_AI_Service_Focus'].apply(clean_percentage)
# Out:
# /tmp/ipykernel_1740/3035192412.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_us['Percent_AI_Service_Focus'] = df_us['Percent_AI_Service_Focus'].apply(clean_percentage)

# %%
df_us.Percent_AI_Service_Focus = df.Percent_AI_Service_Focus.str[:-1]
df_us
# Out:
# /tmp/ipykernel_1740/226604693.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_us.Percent_AI_Service_Focus = df.Percent_AI_Service_Focus.str[:-1]
#                 Company_Name                             Website  \
# 0                   Smith.ai                   https://smith.ai/
# 1                    MooveIt               https://moove-it.com/
# 2               TechSpeedInc           http://www.techspeed.com/
# 3                    WillDom                https://willdom.com/
# 4                     Icreon           https://www.icreon.com/en
# ...                      ...                                 ...
# 3083             SoftwarePro  https://softwaredeveloperspro.com/
# ...

# %%
print(df_us.Percent_AI_Service_Focus.unique())
# Out:
# ['10' '15' '40' '20' '30' '100' '50' '80' '60' '25' '13' '70' '35' '75'
#  '12' '17' '90' '49' '51' '38' '45' '36' '18' '33']

# %%
df_us['Percent_AI_Service_Focus'] = df_us['Percent_AI_Service_Focus'].astype(int)
# Out:
# /tmp/ipykernel_1740/538379273.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_us['Percent_AI_Service_Focus'] = df_us['Percent_AI_Service_Focus'].astype(int)

# %%
# Define a mapping for the levels to numeric values
mapping = {
    "Undisclosed": None,    # You can replace None with any value if needed
    "$50 - $99 / hr": 2,
    "$25 - $49 / hr": 3,
    "$100 - $149 / hr": 4,
    "< $25 / hr": 1,
    "$150 - $199 / hr": 5,
    "$200 - $300 / hr": 6,
    "$300+ / hr": 7,
}

# Drop the "Undisclosed" row
df_us = df_us[df_us["Average_Hourly_Rate"] != "Undisclosed"]

# Map the levels to numeric values
df_us["Hourly_Rate"] = df_us["Average_Hourly_Rate"].map(mapping)
# Out:
# /tmp/ipykernel_1740/2880901226.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_us["Hourly_Rate"] = df_us["Average_Hourly_Rate"].map(mapping)

# %%
df_final = df_us[['state','Percent_AI_Service_Focus', 'Hourly_Rate']]

# %%
df_final
# Out:
#      state  Percent_AI_Service_Focus  Hourly_Rate
# 1       TX                        15          2.0
# 2       OR                        40          1.0
# 3       FL                        10          2.0
# 4       NY                        10          4.0
# 9       NY                        10          2.0
# ...    ...                       ...          ...
# 3083    NV                        10          3.0
# 3089    CA                        20          3.0
# 3095    NJ                        20          3.0
# 3096    CA                        10          3.0
# 3098    IL                        25          2.0
#
# [418 rows x 3 columns]

# %%
df1 = df_final.groupby('state')[['Percent_AI_Service_Focus','Hourly_Rate']].mean().reset_index()

# Rename the columns for clarity
df1.columns = ['State', 'Percent_AI_Service_Focus', 'Hourly_Rate']
df1.Hourly_Rate = df1.Hourly_Rate*300/6

# %%
df1
# Out:
#    State  Percent_AI_Service_Focus  Hourly_Rate
# 0     AR                 47.500000   275.000000
# 1     AZ                 24.000000   150.000000
# 2     CA                 24.810811   162.612613
# 3     CO                 22.000000   173.333333
# 4     CT                 20.000000   200.000000
# 5     DE                 27.583333   133.333333
# 6     FL                 20.448276   151.724138
# 7     GA                 29.555556   144.444444
# 8     IA                 36.666667   166.666667
# 9     IL                 25.526316   165.789474
# 10    IN                 15.600000   180.000000
# 11    KS                 20.000000   100.000000
# 12    MA                 23.214286   167.857143
# 13    MD                 23.333333   150.000000
# 14    MI                 29.285714   185.714286
# 15    MN                 22.571429   171.428571
# 16    MO                 17.500000   175.000000
# 17    MS                 10.000000   100.000000
# 18    NC                 18.461538   138.461538
# ...

# %%
# Dictionary mapping state abbreviations to state names
state_dict = {
    'AL': 'Alabama',
    'AK': 'Alaska',
    'AZ': 'Arizona',
    'AR': 'Arkansas',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'IA': 'Iowa',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'ME': 'Maine',
    'MD': 'Maryland',
    'MA': 'Massachusetts',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MS': 'Mississippi',
    'MO': 'Missouri',
    'MT': 'Montana',
    'NE': 'Nebraska',
    'NV': 'Nevada',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NY': 'New York',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VT': 'Vermont',
    'VA': 'Virginia',
    'WA': 'Washington',
    'WV': 'West Virginia',
    'WI': 'Wisconsin',
    'WY': 'Wyoming'
}

# Convert state abbreviations to state names
df1['State'] = [state_dict[abbr] for abbr in df1['State']]
df1.rename(columns = {'State':"state"},inplace = True)

# %%
df1
# Out:
#              state  Percent_AI_Service_Focus  Hourly_Rate
# 0         Arkansas                 47.500000   275.000000
# 1          Arizona                 24.000000   150.000000
# 2       California                 24.810811   162.612613
# 3         Colorado                 22.000000   173.333333
# 4      Connecticut                 20.000000   200.000000
# 5         Delaware                 27.583333   133.333333
# 6          Florida                 20.448276   151.724138
# 7          Georgia                 29.555556   144.444444
# 8             Iowa                 36.666667   166.666667
# 9         Illinois                 25.526316   165.789474
# 10         Indiana                 15.600000   180.000000
# 11          Kansas                 20.000000   100.000000
# 12   Massachusetts                 23.214286   167.857143
# 13        Maryland                 23.333333   150.000000
# 14        Michigan                 29.285714   185.714286
# ...

# %%
# Import geopandas library
import geopandas as gpd

# Load file
url = "https://raw.githubusercontent.com/holtzy/The-Python-Graph-Gallery/master/static/data/us_states_hexgrid.geojson.json"
geoData = gpd.read_file(url)

# %%
geoData.head(2)
# Out:
#    cartodb_id                created_at                updated_at  label  \
# 0        1219 2015-05-13 22:26:15+00:00 2015-10-05 16:00:16+00:00  Maine
# 1        1217 2015-05-13 22:24:35+00:00 2015-10-05 16:00:16+00:00   R.I.
#
#    bees iso3166_2                   google_name  \
# 0  60.5        ME         Maine (United States)
# 1  47.8        RI  Rhode Island (United States)
#
#                                             geometry
# 0  POLYGON ((-72.62574 55.31320, -69.90286 54.408...
# 1  POLYGON ((-72.62574 49.57439, -69.90286 48.544...

# %%
# Import the geoplot library.
import matplotlib.pyplot as plt

# Set the plot size for this notebook:
plt.rcParams["figure.figsize"]=13,13

# Draw a map with matplotlib
geoData.plot(color="white", edgecolor='black', linewidth=.5);
plt.axis('off');

# %%
# add a "centroid" column with the centroid position of each county
geoData['centroid'] = geoData['geometry'].apply(lambda x: x.centroid)

# redraw the empty hexbin map:
geoData.plot(color="white", edgecolor='black', linewidth=.5)
plt.axis('off')

# for each county, annotate with the county name located at the centroid coordinates 
for idx, row in geoData.iterrows():
    plt.annotate(text=row['iso3166_2'], xy=row['centroid'].coords[0], horizontalalignment='center', va='center')

# %%
geoData.head()
# Out:
#    cartodb_id                created_at                updated_at  label  \
# 0        1219 2015-05-13 22:26:15+00:00 2015-10-05 16:00:16+00:00  Maine
# 1        1217 2015-05-13 22:24:35+00:00 2015-10-05 16:00:16+00:00   R.I.
# 2        1218 2015-05-13 22:25:00+00:00 2015-10-05 16:00:16+00:00    Vt.
# 3         231 2015-05-13 22:02:22+00:00 2015-10-05 16:00:16+00:00  Okla.
# 4         244 2015-05-13 22:02:22+00:00 2015-10-05 16:00:16+00:00   N.C.
#
#    bees iso3166_2                     google_name  \
# 0  60.5        ME           Maine (United States)
# 1  47.8        RI    Rhode Island (United States)
# 2  33.9        VT         Vermont (United States)
# 3  63.4        OK        Oklahoma (United States)
# 4  41.5        NC  North Carolina (United States)
#
#                                             geometry  \
# 0  POLYGON ((-72.62574 55.31320, -69.90286 54.408...
# 1  POLYGON ((-72.62574 49.57439, -69.90286 48.544...
# 2  POLYGON ((-80.79436 52.53744, -78.07148 51.570...
# ...

# %%
# Read the mariage data stored on github:
import pandas as pd
# mariageData = pd.read_csv("https://raw.githubusercontent.com/holtzy/The-Python-Graph-Gallery/master/static/data/State_mariage_rate.csv")
# print(mariageData.head())
# Add a new column to the geo dataframe that will be used for joining:
geoData['state'] = geoData['google_name'].str.replace(r'\(United States\)', '', regex=True).str.strip()

# print(geoData.head())
# # Merge the mariage dataset with the geospatial information
# geoData = geoData.set_index('state').join(mariageData.set_index('state'))

geoData.head()
# Out:
#    cartodb_id                created_at                updated_at  label  \
# 0        1219 2015-05-13 22:26:15+00:00 2015-10-05 16:00:16+00:00  Maine
# 1        1217 2015-05-13 22:24:35+00:00 2015-10-05 16:00:16+00:00   R.I.
# 2        1218 2015-05-13 22:25:00+00:00 2015-10-05 16:00:16+00:00    Vt.
# 3         231 2015-05-13 22:02:22+00:00 2015-10-05 16:00:16+00:00  Okla.
# 4         244 2015-05-13 22:02:22+00:00 2015-10-05 16:00:16+00:00   N.C.
#
#    bees iso3166_2                     google_name  \
# 0  60.5        ME           Maine (United States)
# 1  47.8        RI    Rhode Island (United States)
# 2  33.9        VT         Vermont (United States)
# 3  63.4        OK        Oklahoma (United States)
# 4  41.5        NC  North Carolina (United States)
#
#                                             geometry  \
# 0  POLYGON ((-72.62574 55.31320, -69.90286 54.408...
# 1  POLYGON ((-72.62574 49.57439, -69.90286 48.544...
# 2  POLYGON ((-80.79436 52.53744, -78.07148 51.570...
# ...

# %%
df1.value_counts()
# Out:
# state           Percent_AI_Service_Focus  Hourly_Rate
# Arizona         24.000000                 150.000000     1
# Pennsylvania    27.000000                 200.000000     1
# New Jersey      14.687500                 128.125000     1
# New York        21.703704                 135.185185     1
# North Carolina  18.461538                 138.461538     1
# Ohio            26.666667                 133.333333     1
# Oklahoma        10.000000                 250.000000     1
# Oregon          16.666667                 125.000000     1
# Rhode Island    17.500000                 150.000000     1
# Arkansas        47.500000                 275.000000     1
# Tennessee       10.000000                 225.000000     1
# Texas           18.000000                 135.714286     1
# Utah            35.000000                 120.000000     1
# Virginia        18.333333                 175.000000     1
# Washington      33.928571                 182.142857     1
# ...

# %%
geoData['state'].value_counts()
# Out:
# state
# Maine                   1
# Illinois                1
# Alabama                 1
# Arizona                 1
# Georgia                 1
# Louisiana               1
# Mississippi             1
# Utah                    1
# Colorado                1
# Arkansas                1
# Idaho                   1
# Oregon                  1
# Pennsylvania            1
# Hawaii                  1
# Indiana                 1
# New York                1
# Washington              1
# Wisconsin               1
# Massachusetts           1
# Michigan                1
# Minnesota               1
# Montana                 1
# North Dakota            1
# Alaska                  1
# Texas                   1
# New Hampshire           1
# Rhode Island            1
# Nebraska                1
# Vermont                 1
# Oklahoma                1
# North Carolina          1
# Virginia                1
# West Virginia           1
# California              1
# Kansas                  1
# ...

# %%
print("GeoData state unique count: ", geoData['state'].nunique())
print("GeoData state row count: ", len(geoData))

print("df1 state unique count: ", df1['state'].nunique())
print("df1 state row count: ", len(df1))

print(geoData['state'].dtype)
print(df1['state'].dtype)

print(sorted(geoData['state'].unique()))
print(sorted(df1['state'].unique()))
# Out:
# GeoData state unique count:  51
# GeoData state row count:  51
# df1 state unique count:  34
# df1 state row count:  34
# object
# object
# ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado', 'Connecticut', 'Delaware', 'District of Columbia', 'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland', 'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico', 'New York', 'North Carolina', 'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania', 'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee', 'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington', 'West Virginia', 'Wisconsin', 'Wyoming']
# ...

# %%
# merge the geoData with df1
df_merge = geoData.merge(df1, on = "state", how = 'outer')
df_merge
# Out:
#     cartodb_id                created_at                updated_at   label  \
# 0         1219 2015-05-13 22:26:15+00:00 2015-10-05 16:00:16+00:00   Maine
# 1         1217 2015-05-13 22:24:35+00:00 2015-10-05 16:00:16+00:00    R.I.
# 2         1218 2015-05-13 22:25:00+00:00 2015-10-05 16:00:16+00:00     Vt.
# 3          231 2015-05-13 22:02:22+00:00 2015-10-05 16:00:16+00:00   Okla.
# 4          244 2015-05-13 22:02:22+00:00 2015-10-05 16:00:16+00:00    N.C.
# 5          259 2015-05-13 22:02:22+00:00 2015-10-05 16:00:16+00:00     Va.
# 6          260 2015-05-13 22:02:22+00:00 2015-10-05 16:00:16+00:00   W.Va.
# 7          250 2015-05-13 22:02:22+00:00 2015-10-05 16:00:16+00:00  Calif.
# 8          247 2015-05-13 22:02:22+00:00 2015-10-05 16:00:16+00:00    Kan.
# 9          261 2015-05-13 22:02:22+00:00 2015-10-05 16:00:16+00:00     Ky.
# 10         258 2015-05-13 22:02:22+00:00 2015-10-05 16:00:16+00:00     Md.
# ...

# %%
df_merge.plot(column="Hourly_Rate", cmap="viridis")
# df_merge
# Out:
# <Axes: >

# %%
# Initialize the figure
fig, ax = plt.subplots(1, figsize=(13, 13))

# map counties with the right color:
df_merge.plot(
    ax=ax,
    column="Hourly_Rate", 
    cmap="BuPu", 
    norm=plt.Normalize(vmin=0, vmax=6),
    edgecolor='black', 
    linewidth=.5
)

# Remove useless axis
ax.axis('off')

# Add title, subtitle and author
ax.annotate('Where AI Talent Costs the Most: Arkansas Tops U.S. in Hourly Rates', xy=(10,590),  xycoords='axes pixels', horizontalalignment='left', verticalalignment='top', fontsize=14, color='black')
ax.annotate("Arkansas Leads the Nation in AI Companies' Hourly Rates", xy=(10,560),  xycoords='axes pixels', horizontalalignment='left', verticalalignment='top', fontsize=11, color='#808080')
ax.annotate('https://www.kaggle.com/datasets/vineethakkinapalli/ai-companies/', xy=(650,-10),  xycoords='axes pixels', horizontalalignment='left', verticalalignment='top', fontsize=8, color='#808080')

# for each county, annotate with the county name located at the centroid coordinates 
for idx, row in geoData.iterrows():
    ax.annotate(
        row['iso3166_2'], 
        xy=row['centroid'].coords[0], 
        horizontalalignment='center', 
        verticalalignment='center',
        color="white"
    )
    


# Add a color bar
sm = plt.cm.ScalarMappable(cmap='BuPu', norm=plt.Normalize(vmin=0, vmax=6))
fig.colorbar(sm, orientation="horizontal", aspect=50, fraction=0.005, pad=0 )
# Out:
# /tmp/ipykernel_1740/3907184671.py:36: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   fig.colorbar(sm, orientation="horizontal", aspect=50, fraction=0.005, pad=0 )

# %%
# Initialize the figure
fig, ax = plt.subplots(1, figsize=(13, 13))

# map counties with the right color:
# map counties with the right color:
df_merge.plot(
    ax=ax,
    column="Hourly_Rate", 
    cmap="BuPu", 
    norm=plt.Normalize(vmin=0, vmax=300),
    edgecolor='black', 
    linewidth=.5,
    missing_kwds={
        "color": "lightgrey",
        "edgecolor": "grey",
        "hatch": "/",
        "label": "Missing values",
    }
)

# Remove useless axis
ax.axis('off')

# Add title, subtitle and author
ax.annotate('Where AI Talent Costs the Most: Arkansas Tops U.S. in Hourly Rates', xy=(10,600),  xycoords='axes pixels', horizontalalignment='left', verticalalignment='top', fontsize=14, color='black')
ax.annotate("Arkansas Leads the Nation in AI Companies' Hourly Rates", xy=(10,580),  xycoords='axes pixels', horizontalalignment='left', verticalalignment='top', fontsize=11, color='#808080')
ax.annotate('https://www.kaggle.com/datasets/vineethakkinapalli/ai-companies/', xy=(650,-60),  xycoords='axes pixels', horizontalalignment='left', verticalalignment='top', fontsize=8, color='#808080')

# for each county, annotate with the county name located at the centroid coordinates 
for idx, row in df_merge.iterrows():
    ax.annotate(
        row['iso3166_2'], 
        xy=row['centroid'].coords[0], 
        # xytext=(0,0),
        horizontalalignment='center', 
        verticalalignment='center',
        color="black"
    )
    ax.annotate(
        str(row['Hourly_Rate'])[:3], 
        xy=row['centroid'].coords[0], 
        xytext=(0,-15),
        textcoords='offset points',
        horizontalalignment='center', 
        verticalalignment='bottom',
        color="black"
    )

# Add a color bar
sm = plt.cm.ScalarMappable(cmap='BuPu', norm=plt.Normalize(vmin=0, vmax=300))
cbar = fig.colorbar(sm, orientation="horizontal", aspect=50, fraction=0.005, pad=0 )

# Add units to the color bar
cbar.set_label('Dollar/Hour', rotation=0, labelpad=10)
# Out:
# /tmp/ipykernel_1740/2082692170.py:51: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = fig.colorbar(sm, orientation="horizontal", aspect=50, fraction=0.005, pad=0 )

# %%
# save the figure 
fig.savefig("AI_Companies.png")
